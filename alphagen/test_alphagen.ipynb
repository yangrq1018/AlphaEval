# %%
import sys
import os
print(os.getcwd())
# %cd /data/home/dinghj/zr-alphagen/zr-alpha-training-base/paper/alphagen
from alphagen.data.calculator import AlphaCalculator
# Out:
# /data/home/dinghj
# /data/home/dinghj/zr-alphagen/zr-alpha-training-base/paper/alphagen
